# %%
# %pip install genomenotebook
# %pip install pandas
# Out:
# Collecting genomenotebook
#   Obtaining dependency information for genomenotebook from https://files.pythonhosted.org/packages/30/f9/53fac4486d939fc9353692d8aa0be4178a50c78eda11674060ab6d61e8a5/genomenotebook-0.8.9-py3-none-any.whl.metadata
#   Downloading genomenotebook-0.8.9-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: numpy>=1.23.5 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from genomenotebook) (1.25.2)
# Requirement already satisfied: biopython>=1.78 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from genomenotebook) (1.81)
# Collecting pandas>=1.5.3 (from genomenotebook)
#   Obtaining dependency information for pandas>=1.5.3 from https://files.pythonhosted.org/packages/d0/28/88b81881c056376254618fad622a5e94b5126db8c61157ea1910cd1c040a/pandas-2.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pandas-2.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting bokeh>=3.1.0 (from genomenotebook)
#   Obtaining dependency information for bokeh>=3.1.0 from https://files.pythonhosted.org/packages/c6/5d/46cde55344ad96a0570e2f72d9df428349a6a800448f6a5b6140c337f930/bokeh-3.2.1-py3-none-any.whl.metadata
#   Downloading bokeh-3.2.1-py3-none-any.whl.metadata (12 kB)
# Collecting fastcore (from genomenotebook)
#   Downloading fastcore-1.5.29-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting jupyter (from genomenotebook)
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting selenium (from genomenotebook)
#   Obtaining dependency information for selenium from https://files.pythonhosted.org/packages/10/56/8288d1813a68c1e0638515dbb777fce6d87d0d240e683216f956145310e6/selenium-4.11.2-py3-none-any.whl.metadata
#   Downloading selenium-4.11.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting svgutils (from genomenotebook)
#   Downloading svgutils-0.3.4-py3-none-any.whl (10 kB)
# Collecting Jinja2>=2.9 (from bokeh>=3.1.0->genomenotebook)
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 2.9 MB/s eta 0:00:00a 0:00:01
# Collecting contourpy>=1 (from bokeh>=3.1.0->genomenotebook)
#   Obtaining dependency information for contourpy>=1 from https://files.pythonhosted.org/packages/d8/23/8d968922459b1c8a2c6ffca28fac00324b06b3a0633be2a39b0b1c3f84ab/contourpy-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading contourpy-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.7 kB)
# Requirement already satisfied: packaging>=16.8 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from bokeh>=3.1.0->genomenotebook) (23.1)
# Collecting pillow>=7.1.0 (from bokeh>=3.1.0->genomenotebook)
#   Obtaining dependency information for pillow>=7.1.0 from https://files.pythonhosted.org/packages/16/89/818fa238e37a47a29bb8495ca2cafdd514599a89f19ada7916348a74b5f9/Pillow-10.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata
#   Downloading Pillow-10.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: PyYAML>=3.10 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from bokeh>=3.1.0->genomenotebook) (6.0)
# Requirement already satisfied: tornado>=5.1 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from bokeh>=3.1.0->genomenotebook) (6.3.2)
# Collecting xyzservices>=2021.09.1 (from bokeh>=3.1.0->genomenotebook)
#   Obtaining dependency information for xyzservices>=2021.09.1 from https://files.pythonhosted.org/packages/50/d7/2ca7f65c189aa71b5a9dfeaabc0b4ab8d50bead74a7863428c579737d625/xyzservices-2023.7.0-py3-none-any.whl.metadata
#   Downloading xyzservices-2023.7.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from pandas>=1.5.3->genomenotebook) (2.8.2)
# Collecting pytz>=2020.1 (from pandas>=1.5.3->genomenotebook)
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 8.7 MB/s eta 0:00:00a 0:00:01
# Collecting tzdata>=2022.1 (from pandas>=1.5.3->genomenotebook)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 45.5 MB/s eta 0:00:00
# Requirement already satisfied: pip in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from fastcore->genomenotebook) (23.2.1)
# Collecting notebook (from jupyter->genomenotebook)
#   Obtaining dependency information for notebook from https://files.pythonhosted.org/packages/85/76/51777158391e1784cc5a892ff355fd0a0b0b5189aeffce9baf51f514b9a2/notebook-7.0.2-py3-none-any.whl.metadata
#   Downloading notebook-7.0.2-py3-none-any.whl.metadata (10 kB)
# Collecting qtconsole (from jupyter->genomenotebook)
#   Downloading qtconsole-5.4.3-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 31.2 MB/s eta 0:00:00
# Collecting jupyter-console (from jupyter->genomenotebook)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting nbconvert (from jupyter->genomenotebook)
#   Obtaining dependency information for nbconvert from https://files.pythonhosted.org/packages/51/bd/ede955c9e981abf6d0e12a7583fd0f9256eedfb461073f25045770f3e717/nbconvert-7.7.3-py3-none-any.whl.metadata
#   Downloading nbconvert-7.7.3-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: ipykernel in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from jupyter->genomenotebook) (6.25.1)
# Collecting ipywidgets (from jupyter->genomenotebook)
#   Obtaining dependency information for ipywidgets from https://files.pythonhosted.org/packages/b8/d4/ce436660098b2f456e2b8fdf76d4f33cbc3766c874c4aa2f772c7a5e943f/ipywidgets-8.1.0-py3-none-any.whl.metadata
#   Downloading ipywidgets-8.1.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from selenium->genomenotebook) (2.0.4)
# Collecting trio~=0.17 (from selenium->genomenotebook)
#   Obtaining dependency information for trio~=0.17 from https://files.pythonhosted.org/packages/a3/dd/b61fa61b186d3267ef3903048fbee29132963ae762fb70b08d4a3cd6f7aa/trio-0.22.2-py3-none-any.whl.metadata
#   Downloading trio-0.22.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting trio-websocket~=0.9 (from selenium->genomenotebook)
#   Obtaining dependency information for trio-websocket~=0.9 from https://files.pythonhosted.org/packages/a5/a6/06e2373f95c12e9e8f6b910a76c86e375348ead77ab476230640666310fb/trio_websocket-0.10.3-py3-none-any.whl.metadata
#   Downloading trio_websocket-0.10.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from selenium->genomenotebook) (2023.7.22)
# Collecting lxml (from svgutils->genomenotebook)
#   Obtaining dependency information for lxml from https://files.pythonhosted.org/packages/ed/62/ffc30348ae141f69f9f23b65ba769db7ca209856c9a9b3406279e0ea24de/lxml-4.9.3-cp311-cp311-manylinux_2_28_x86_64.whl.metadata
#   Downloading lxml-4.9.3-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting MarkupSafe>=2.0 (from Jinja2>=2.9->bokeh>=3.1.0->genomenotebook)
#   Obtaining dependency information for MarkupSafe>=2.0 from https://files.pythonhosted.org/packages/fe/21/2eff1de472ca6c99ec3993eab11308787b9879af9ca8bbceb4868cf4f2ca/MarkupSafe-2.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading MarkupSafe-2.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: six>=1.5 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->genomenotebook) (1.16.0)
# Collecting attrs>=20.1.0 (from trio~=0.17->selenium->genomenotebook)
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 18.0 MB/s eta 0:00:00
# Collecting sortedcontainers (from trio~=0.17->selenium->genomenotebook)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: idna in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from trio~=0.17->selenium->genomenotebook) (3.4)
# Collecting outcome (from trio~=0.17->selenium->genomenotebook)
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Collecting sniffio (from trio~=0.17->selenium->genomenotebook)
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting exceptiongroup (from trio-websocket~=0.9->selenium->genomenotebook)
#   Obtaining dependency information for exceptiongroup from https://files.pythonhosted.org/packages/fe/17/f43b7c9ccf399d72038042ee72785c305f6c6fdc6231942f8ab99d995742/exceptiongroup-1.1.2-py3-none-any.whl.metadata
#   Downloading exceptiongroup-1.1.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium->genomenotebook)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium->genomenotebook) (1.7.1)
# Requirement already satisfied: comm>=0.1.1 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from ipykernel->jupyter->genomenotebook) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from ipykernel->jupyter->genomenotebook) (1.6.8)
# Requirement already satisfied: ipython>=7.23.1 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from ipykernel->jupyter->genomenotebook) (8.14.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from ipykernel->jupyter->genomenotebook) (8.3.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from ipykernel->jupyter->genomenotebook) (5.3.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from ipykernel->jupyter->genomenotebook) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from ipykernel->jupyter->genomenotebook) (1.5.6)
# Requirement already satisfied: psutil in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from ipykernel->jupyter->genomenotebook) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from ipykernel->jupyter->genomenotebook) (25.1.1)
# Requirement already satisfied: traitlets>=5.4.0 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from ipykernel->jupyter->genomenotebook) (5.9.0)
# Collecting widgetsnbextension~=4.0.7 (from ipywidgets->jupyter->genomenotebook)
#   Obtaining dependency information for widgetsnbextension~=4.0.7 from https://files.pythonhosted.org/packages/8e/d4/d31b12ac0b87e8cc9fdb6ea1eb6596de405eaaa2f25606aaa755d0eebbc0/widgetsnbextension-4.0.8-py3-none-any.whl.metadata
#   Downloading widgetsnbextension-4.0.8-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.7 (from ipywidgets->jupyter->genomenotebook)
#   Obtaining dependency information for jupyterlab-widgets~=3.0.7 from https://files.pythonhosted.org/packages/74/5e/2475ac62faf2e342b2bf20b8d8e375f49400ecb38f52e4e0a7557eb1cedb/jupyterlab_widgets-3.0.8-py3-none-any.whl.metadata
#   Downloading jupyterlab_widgets-3.0.8-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from jupyter-console->jupyter->genomenotebook) (3.0.39)
# Requirement already satisfied: pygments in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from jupyter-console->jupyter->genomenotebook) (2.16.1)
# Collecting beautifulsoup4 (from nbconvert->jupyter->genomenotebook)
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 33.6 MB/s eta 0:00:00
# Collecting bleach!=5.0.0 (from nbconvert->jupyter->genomenotebook)
#   Downloading bleach-6.0.0-py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 kB 35.2 MB/s eta 0:00:00
# Collecting defusedxml (from nbconvert->jupyter->genomenotebook)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting jupyterlab-pygments (from nbconvert->jupyter->genomenotebook)
#   Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert->jupyter->genomenotebook)
#   Obtaining dependency information for mistune<4,>=2.0.3 from https://files.pythonhosted.org/packages/cc/c0/ac9587149e37cde62ae338e9db8241ae2fdc79a84bde8c8ba7caea2c22d8/mistune-3.0.1-py3-none-any.whl.metadata
#   Downloading mistune-3.0.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter->genomenotebook)
#   Obtaining dependency information for nbclient>=0.5.0 from https://files.pythonhosted.org/packages/ac/5a/d670ca51e6c3d98574b9647599821590efcd811d71f58e9c89fc59a17685/nbclient-0.8.0-py3-none-any.whl.metadata
#   Downloading nbclient-0.8.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting nbformat>=5.7 (from nbconvert->jupyter->genomenotebook)
#   Obtaining dependency information for nbformat>=5.7 from https://files.pythonhosted.org/packages/f4/e7/ef30a90b70eba39e675689b9eaaa92530a71d7435ab8f9cae520814e0caf/nbformat-5.9.2-py3-none-any.whl.metadata
#   Downloading nbformat-5.9.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter->genomenotebook)
#   Downloading pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting tinycss2 (from nbconvert->jupyter->genomenotebook)
#   Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting jupyter-server<3,>=2.4.0 (from notebook->jupyter->genomenotebook)
#   Obtaining dependency information for jupyter-server<3,>=2.4.0 from https://files.pythonhosted.org/packages/f2/8f/914785ff2a0c4e2a7e15217710d57568f6ed6a84befa83a5a8c8b22ed3c6/jupyter_server-2.7.0-py3-none-any.whl.metadata
#   Downloading jupyter_server-2.7.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting jupyterlab-server<3,>=2.22.1 (from notebook->jupyter->genomenotebook)
#   Obtaining dependency information for jupyterlab-server<3,>=2.22.1 from https://files.pythonhosted.org/packages/a7/0d/6d4eab0391bd4df1c43f308368d5e177b0fa8ac632267222a23b71317091/jupyterlab_server-2.24.0-py3-none-any.whl.metadata
#   Downloading jupyterlab_server-2.24.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyterlab<5,>=4.0.2 (from notebook->jupyter->genomenotebook)
#   Obtaining dependency information for jupyterlab<5,>=4.0.2 from https://files.pythonhosted.org/packages/db/1d/a4645d6385cd03aa7703a8695317b431e92460a5a9168b9fac59d2aafd60/jupyterlab-4.0.4-py3-none-any.whl.metadata
#   Downloading jupyterlab-4.0.4-py3-none-any.whl.metadata (15 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook->jupyter->genomenotebook)
#   Downloading notebook_shim-0.2.3-py3-none-any.whl (13 kB)
# Collecting ipython-genutils (from qtconsole->jupyter->genomenotebook)
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting qtpy>=2.0.1 (from qtconsole->jupyter->genomenotebook)
#   Downloading QtPy-2.3.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 24.0 MB/s eta 0:00:00
# Collecting webencodings (from bleach!=5.0.0->nbconvert->jupyter->genomenotebook)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: backcall in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->genomenotebook) (0.2.0)
# Requirement already satisfied: decorator in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->genomenotebook) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->genomenotebook) (0.19.0)
# Requirement already satisfied: pickleshare in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->genomenotebook) (0.7.5)
# Requirement already satisfied: stack-data in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->genomenotebook) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->genomenotebook) (4.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->genomenotebook) (3.10.0)
# Collecting anyio>=3.1.0 (from jupyter-server<3,>=2.4.0->notebook->jupyter->genomenotebook)
#   Obtaining dependency information for anyio>=3.1.0 from https://files.pythonhosted.org/packages/19/24/44299477fe7dcc9cb58d0a57d5a7588d6af2ff403fdd2d47a246c91a3246/anyio-3.7.1-py3-none-any.whl.metadata
#   Using cached anyio-3.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting argon2-cffi (from jupyter-server<3,>=2.4.0->notebook->jupyter->genomenotebook)
#   Downloading argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting jupyter-events>=0.6.0 (from jupyter-server<3,>=2.4.0->notebook->jupyter->genomenotebook)
#   Obtaining dependency information for jupyter-events>=0.6.0 from https://files.pythonhosted.org/packages/15/0d/3c67f6c432d8085a3cee250e1e235f27b764be90cc2d16fdcc0b1cee9572/jupyter_events-0.7.0-py3-none-any.whl.metadata
#   Downloading jupyter_events-0.7.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting jupyter-server-terminals (from jupyter-server<3,>=2.4.0->notebook->jupyter->genomenotebook)
#   Downloading jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Collecting overrides (from jupyter-server<3,>=2.4.0->notebook->jupyter->genomenotebook)
#   Obtaining dependency information for overrides from https://files.pythonhosted.org/packages/da/28/3fa6ef8297302fc7b3844980b6c5dbc71cdbd4b61e9b2591234214d5ab39/overrides-7.4.0-py3-none-any.whl.metadata
#   Downloading overrides-7.4.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting prometheus-client (from jupyter-server<3,>=2.4.0->notebook->jupyter->genomenotebook)
#   Obtaining dependency information for prometheus-client from https://files.pythonhosted.org/packages/ad/b3/6e18c89bf6bd120590ea538a62cae16dc763ff2745b18377c4be5495c4aa/prometheus_client-0.17.1-py3-none-any.whl.metadata
#   Downloading prometheus_client-0.17.1-py3-none-any.whl.metadata (24 kB)
# Collecting send2trash (from jupyter-server<3,>=2.4.0->notebook->jupyter->genomenotebook)
#   Downloading Send2Trash-1.8.2-py3-none-any.whl (18 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->notebook->jupyter->genomenotebook)
#   Downloading terminado-0.17.1-py3-none-any.whl (17 kB)
# Collecting websocket-client (from jupyter-server<3,>=2.4.0->notebook->jupyter->genomenotebook)
#   Obtaining dependency information for websocket-client from https://files.pythonhosted.org/packages/d3/a3/63e9329c8cc9be6153e919e17d0ef5b60d537fed78564872951b95bcc17c/websocket_client-1.6.1-py3-none-any.whl.metadata
#   Downloading websocket_client-1.6.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting async-lru>=1.0.0 (from jupyterlab<5,>=4.0.2->notebook->jupyter->genomenotebook)
#   Obtaining dependency information for async-lru>=1.0.0 from https://files.pythonhosted.org/packages/fa/9f/3c3503693386c4b0f245eaf5ca6198e3b28879ca0a40bde6b0e319793453/async_lru-2.0.4-py3-none-any.whl.metadata
#   Downloading async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<5,>=4.0.2->notebook->jupyter->genomenotebook)
#   Obtaining dependency information for jupyter-lsp>=2.0.0 from https://files.pythonhosted.org/packages/8f/b6/a1571e48550855a79898f851f57e5858b00eb36b09ea3b1a8bb65c53a290/jupyter_lsp-2.2.0-py3-none-any.whl.metadata
#   Downloading jupyter_lsp-2.2.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->genomenotebook)
#   Downloading Babel-2.12.1-py3-none-any.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 20.6 MB/s eta 0:00:0000:010:01
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->genomenotebook)
#   Obtaining dependency information for json5>=0.9.0 from https://files.pythonhosted.org/packages/70/ba/fa37123a86ae8287d6678535a944f9c3377d8165e536310ed6f6cb0f0c0e/json5-0.9.14-py2.py3-none-any.whl.metadata
#   Downloading json5-0.9.14-py2.py3-none-any.whl.metadata (10 kB)
# Collecting jsonschema>=4.17.3 (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->genomenotebook)
#   Obtaining dependency information for jsonschema>=4.17.3 from https://files.pythonhosted.org/packages/2b/ff/af59fd34bc4d7ac3e6e0cd1f3c10317d329b6c1aee179e8b24ad9a79fbac/jsonschema-4.19.0-py3-none-any.whl.metadata
#   Downloading jsonschema-4.19.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: requests>=2.28 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->genomenotebook) (2.31.0)
# Collecting fastjsonschema (from nbformat>=5.7->nbconvert->jupyter->genomenotebook)
#   Obtaining dependency information for fastjsonschema from https://files.pythonhosted.org/packages/9d/93/a3ca3cdeb84065d7d8f8df4cb09ab44405f109183c1d2b915ec17574e6b1/fastjsonschema-2.18.0-py3-none-any.whl.metadata
#   Downloading fastjsonschema-2.18.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: wcwidth in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->genomenotebook) (0.2.6)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium->genomenotebook)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert->jupyter->genomenotebook)
#   Downloading soupsieve-2.4.1-py3-none-any.whl (36 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->genomenotebook) (0.8.3)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->genomenotebook)
#   Obtaining dependency information for jsonschema-specifications>=2023.03.6 from https://files.pythonhosted.org/packages/1c/24/83349ac2189cc2435e84da3f69ba3c97314d3c0622628e55171c6798ed80/jsonschema_specifications-2023.7.1-py3-none-any.whl.metadata
#   Downloading jsonschema_specifications-2023.7.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->genomenotebook)
#   Obtaining dependency information for referencing>=0.28.4 from https://files.pythonhosted.org/packages/be/8e/56d6f1e2d591f4d6cbcba446cac4a1b0dc4f584537e2071d9bcee8eeab6b/referencing-0.30.2-py3-none-any.whl.metadata
#   Downloading referencing-0.30.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->genomenotebook)
#   Obtaining dependency information for rpds-py>=0.7.1 from https://files.pythonhosted.org/packages/d3/65/bef74a9023a266ae3582f56eb2e78c4e92903c30a15810f42045c2d68cb9/rpds_py-0.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading rpds_py-0.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->genomenotebook)
#   Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->genomenotebook)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->genomenotebook)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->genomenotebook) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.22.1->notebook->jupyter->genomenotebook) (3.2.0)
# Collecting argon2-cffi-bindings (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->genomenotebook)
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 23.9 MB/s eta 0:00:00
# Requirement already satisfied: executing>=1.2.0 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->genomenotebook) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->genomenotebook) (2.2.1)
# Requirement already satisfied: pure-eval in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->genomenotebook) (0.2.2)
# Collecting fqdn (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->genomenotebook)
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->genomenotebook)
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13 (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->genomenotebook)
#   Obtaining dependency information for jsonpointer>1.13 from https://files.pythonhosted.org/packages/12/f6/0232cc0c617e195f06f810534d00b74d2f348fe71b2118009ad8ad31f878/jsonpointer-2.4-py2.py3-none-any.whl.metadata
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting uri-template (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->genomenotebook)
#   Obtaining dependency information for uri-template from https://files.pythonhosted.org/packages/e7/00/3fca040d7cf8a32776d3d81a00c8ee7457e00f80c649f1e4a863c8321ae9/uri_template-1.3.0-py3-none-any.whl.metadata
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->genomenotebook)
#   Downloading webcolors-1.13-py3-none-any.whl (14 kB)
# Requirement already satisfied: cffi>=1.0.1 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->genomenotebook) (1.15.1)
# Requirement already satisfied: pycparser in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->genomenotebook) (2.21)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->genomenotebook)
#   Downloading arrow-1.2.3-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 19.1 MB/s eta 0:00:00
# Downloading genomenotebook-0.8.9-py3-none-any.whl (21.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.6/21.6 MB 27.8 MB/s eta 0:00:0000:0100:01
# Downloading bokeh-3.2.1-py3-none-any.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 47.8 MB/s eta 0:00:0000:0100:01
# Downloading pandas-2.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 57.8 MB/s eta 0:00:0000:010:01
# Downloading selenium-4.11.2-py3-none-any.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 61.5 MB/s eta 0:00:0000:0100:01m
# Downloading contourpy-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 51.5 MB/s eta 0:00:00
# Downloading Pillow-10.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 61.9 MB/s eta 0:00:00ta 0:00:01
# Downloading trio-0.22.2-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.2/400.2 kB 57.1 MB/s eta 0:00:00
# Downloading trio_websocket-0.10.3-py3-none-any.whl (17 kB)
# Downloading xyzservices-2023.7.0-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 12.8 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.0-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 34.8 MB/s eta 0:00:00
# Downloading lxml-4.9.3-cp311-cp311-manylinux_2_28_x86_64.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 64.1 MB/s eta 0:00:0000:0100:01m
# Downloading nbconvert-7.7.3-py3-none-any.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 47.9 MB/s eta 0:00:00
# Downloading notebook-7.0.2-py3-none-any.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 60.6 MB/s eta 0:00:00ta 0:00:01
# Downloading jupyter_server-2.7.0-py3-none-any.whl (375 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.1/375.1 kB 53.9 MB/s eta 0:00:00
# Downloading jupyterlab-4.0.4-py3-none-any.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 63.3 MB/s eta 0:00:0000:0100:01m
# Downloading jupyterlab_server-2.24.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 18.0 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.8-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 kB 44.6 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Downloading mistune-3.0.1-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 14.4 MB/s eta 0:00:00
# Downloading nbclient-0.8.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 20.8 MB/s eta 0:00:00
# Downloading nbformat-5.9.2-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.6/77.6 kB 12.8 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.8-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 82.8 MB/s eta 0:00:00
# Downloading exceptiongroup-1.1.2-py3-none-any.whl (14 kB)
# Using cached anyio-3.7.1-py3-none-any.whl (80 kB)
# Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Downloading json5-0.9.14-py2.py3-none-any.whl (19 kB)
# Downloading jsonschema-4.19.0-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 kB 24.8 MB/s eta 0:00:00
# Downloading jupyter_events-0.7.0-py3-none-any.whl (18 kB)
# Downloading jupyter_lsp-2.2.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 19.3 MB/s eta 0:00:00
# Downloading fastjsonschema-2.18.0-py3-none-any.whl (23 kB)
# Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Downloading prometheus_client-0.17.1-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 18.8 MB/s eta 0:00:00
# Downloading websocket_client-1.6.1-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 17.2 MB/s eta 0:00:00
# Downloading jsonschema_specifications-2023.7.1-py3-none-any.whl (17 kB)
# Downloading referencing-0.30.2-py3-none-any.whl (25 kB)
# Downloading rpds_py-0.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 69.0 MB/s eta 0:00:00
# Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webencodings, sortedcontainers, pytz, json5, ipython-genutils, fastjsonschema, xyzservices, widgetsnbextension, websocket-client, webcolors, uri-template, tzdata, tinycss2, terminado, soupsieve, sniffio, send2trash, rpds-py, rfc3986-validator, rfc3339-validator, qtpy, python-json-logger, prometheus-client, pillow, pandocfilters, overrides, mistune, MarkupSafe, lxml, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, h11, fqdn, fastcore, exceptiongroup, defusedxml, contourpy, bleach, babel, attrs, async-lru, wsproto, svgutils, referencing, pandas, outcome, jupyter-server-terminals, Jinja2, beautifulsoup4, arrow, argon2-cffi-bindings, anyio, trio, jsonschema-specifications, isoduration, bokeh, argon2-cffi, trio-websocket, jsonschema, ipywidgets, selenium, qtconsole, nbformat, jupyter-console, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter, genomenotebook
# Successfully installed Jinja2-3.1.2 MarkupSafe-2.1.3 anyio-3.7.1 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 arrow-1.2.3 async-lru-2.0.4 attrs-23.1.0 babel-2.12.1 beautifulsoup4-4.12.2 bleach-6.0.0 bokeh-3.2.1 contourpy-1.1.0 defusedxml-0.7.1 exceptiongroup-1.1.2 fastcore-1.5.29 fastjsonschema-2.18.0 fqdn-1.5.1 genomenotebook-0.8.9 h11-0.14.0 ipython-genutils-0.2.0 ipywidgets-8.1.0 isoduration-20.11.0 json5-0.9.14 jsonpointer-2.4 jsonschema-4.19.0 jsonschema-specifications-2023.7.1 jupyter-1.0.0 jupyter-console-6.6.3 jupyter-events-0.7.0 jupyter-lsp-2.2.0 jupyter-server-2.7.0 jupyter-server-terminals-0.4.4 jupyterlab-4.0.4 jupyterlab-pygments-0.2.2 jupyterlab-server-2.24.0 jupyterlab-widgets-3.0.8 lxml-4.9.3 mistune-3.0.1 nbclient-0.8.0 nbconvert-7.7.3 nbformat-5.9.2 notebook-7.0.2 notebook-shim-0.2.3 outcome-1.2.0 overrides-7.4.0 pandas-2.0.3 pandocfilters-1.5.0 pillow-10.0.0 prometheus-client-0.17.1 python-json-logger-2.0.7 pytz-2023.3 qtconsole-5.4.3 qtpy-2.3.1 referencing-0.30.2 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.9.2 selenium-4.11.2 send2trash-1.8.2 sniffio-1.3.0 sortedcontainers-2.4.0 soupsieve-2.4.1 svgutils-0.3.4 terminado-0.17.1 tinycss2-1.2.1 trio-0.22.2 trio-websocket-0.10.3 tzdata-2023.3 uri-template-1.3.0 webcolors-1.13 webencodings-0.5.1 websocket-client-1.6.1 widgetsnbextension-4.0.8 wsproto-1.2.0 xyzservices-2023.7.0
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /home/pchesnokova/miniconda3/envs/bakta/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import genomenotebook as gn

# %%
def get_operon_coords(one_operon):
    if one_operon['strand'].iloc[0] == '+':
        start = one_operon['start'].min()
        end = one_operon['end'].max()
    else:
        start = one_operon['end'].max()
        end = one_operon['start'].min()

    return pd.Series({'start': start, 'end': end,
                      'strand': one_operon['strand'].iloc[0],
                      'N_genes': len(one_operon),
                     })

def extract_operons(operons_genes):
    operons = operons_genes.groupby('operon').apply(get_operon_coords).reset_index()
    operons['left'] = operons[['start', 'end']].min(axis=1)
    operons['right'] = operons[['start', 'end']].max(axis=1)
    operons['color'] = 'lightblue'
    operons['type'] = 'region'
    return operons

# %%
from collections import defaultdict
from bokeh.io.output import output_file

gff_path = './data_2/results/final/o_antigen_operons.gff3'
gff = gn.parse_gff(gff_path)
operons = extract_operons(gff)

import random

glyphs=gn.get_default_glyphs()
glyphs = {
    'CDS': gn.Glyph(
        glyph_type="arrow", 
        colors="blue", 
        height=0.7,
        show_name=True
    ),
    'transposon': gn.Glyph(
        glyph_type="arrow", 
        colors="red", 
        height=0.7,
        show_name=True
    )
}


g=gn.GenomeBrowser(
    gff_path=gff_path, #genome_path=genome_path,
    glyphs=glyphs, 
    feature_types=['CDS', 'transposon'],
    height=400,
    width=1200,
    init_pos=618013,
    feature_height=0.1,
    attributes = ["gene_name","function","start","end"],
)

print(operons)
g.highlight(data=operons, hover_data=['operon', 'N_genes'])

'AGOPJMEK_00551'
output_file('operons.html')
g.show()
# Out:
#   operon    start      end strand  N_genes     left    right      color  \
# 0   1860  3666749  3645471      -       20  3645471  3666749  lightblue
# 1   2267  4518297  4506017      -       14  4506017  4518297  lightblue
# 2     44    73698    81565      +        8    73698    81565  lightblue
# 3     46    86913    84884      -        4    84884    86913  lightblue
# 4    705  1493997  1488172      -        7  1488172  1493997  lightblue
# 5    804  1711698  1730261      +       17  1711698  1730261  lightblue
# 6    806  1734614  1746345      +       13  1734614  1746345  lightblue
#
#      type
# 0  region
# 1  region
# 2  region
# 3  region
# 4  region
# 5  region
# 6  region
#   <div id="e19feb58-54dc-4c2b-9494-394cb4459f06" data-root-id="p1232" style="display: contents;"></div>
